# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import math

# %%
np.log(0.000076)
# Out:
# -9.484777217677943

# %%
[0.000109,0.000079,0.000193,0.00151,0.0225,0.326,7.35]

# %%
arr= np.array(np.log([0.000076, 0.000084, 0.00208, 0.07645, 2.96, 54.46, 1175.62]))
arr2= np.array(np.log([0.000109,0.000079,0.000193,0.00151,0.0225,0.326,7.35]))
arr3= np.array(np.log([0.000107,0.000136,0.000349,0.00117,0.00803,0.01975,0.1723,2.78]))



plt.plot(arr, label="ucs")
plt.legend()
plt.plot(arr2, label="misplaced")
plt.legend()
plt.plot(arr3, label= "manhattan")
plt.legend()

# %%
arr= np.array([0.000076, 0.000084, 0.00208, 0.07645, 2.96, 54.46, 1175.62])
arr2= np.array([0.000109,0.000079,0.000193,0.00151,0.0225,0.326,7.35])
arr3= np.array([0.000107,0.000136,0.000349,0.00117,0.00803,0.01975,0.1723,2.78])



plt.plot(arr, label="ucs")
plt.legend()
plt.plot(arr2, label="misplaced")
plt.legend()
plt.plot(arr3, label= "manhattan")
plt.legend()

# %%
node1= np.log([3,16,172,1295,8554,36457,98813])
node2= np.log([2,4,18,119,657,2703, 13621])
node3= np.log([2,4,12,31,160,371,1567,7615])

# %%
plt.plot(node1)
plt.plot(node2)
plt.plot(node3)
